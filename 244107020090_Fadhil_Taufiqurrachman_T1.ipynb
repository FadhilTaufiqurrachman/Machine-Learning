# %% [markdown]
# <a href="https://colab.research.google.com/github/FadhilTaufiqurrachman/Machine-Learning/blob/main/244107020090_Fadhil_Taufiqurrachman_T1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Tugas Praktikum 1
#
# NIM : 244107020090
#
# Nama : Fadhil Taufiqurrachman
#
# Kelas : TI 3G
#
# No Absen : 06
#
# Mata Kuliah : Pembelajaran Mesin

# %% [markdown]
# **Bagian 1**

# %%
# !pip install PyPREP
# !pip install scipy
# !pip install wandb
# !pip install pyECG
# Out:
# ...
#   Using cached pyECG-0.0.9.1-py2.py3-none-any.whl.metadata (3.1 kB)
# ...
#   Using cached ishneholterlib-2017.4.11.tar.gz (7.0 kB)
#   Preparing metadata (setup.py) ... done
# ...
#   Using cached wfdb-2.2.1.tar.gz (94 kB)
#   Preparing metadata (setup.py) ... done
# ...
#   Using cached pytest_cov-7.1.0-py3-none-any.whl.metadata (32 kB)
# ...
#   Using cached pycrc-0.11.0-py3-none-any.whl.metadata (2.7 kB)
# ...
#   Using cached nose-1.3.7-py3-none-any.whl.metadata (1.7 kB)
# ...
#   Using cached sklearn-0.0.post12.tar.gz (2.6 kB)
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 257.5/257.5 kB 1.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.7/154.7 kB 4.7 MB/s eta 0:00:00
# ...
#   Created wheel for ishneholterlib: filename=ishneholterlib-2017.4.11-py3-none-any.whl size=7504 sha256=46cef6f18d933eaba87ae7c7487d6091323dba1f1270fe83277691551b2c3bbf
#   Stored in directory: /root/.cache/pip/wheels/60/50/d1/db6b1d062f56ed24c391a2d51126d1341cc51381bed8a2de61
# ...

# %% [markdown]
# Berikut adalah penjelasan dari library yang diimport.
# *   PyPREP : Library yang digunakan sebagai standart pipeline untuk memproses data sinyal Electroencephalography (EEG), berguna dalam membersihkan artefak dan noise pada data otak sebelum dianalisis.
# *   SciPy: Library penting untuk komputasi di Python yang menyediakan fungsi matematika lanjutan, optimasi, integrasi, dan pemrosesan sinyal yang lebih kompleks dibandingkan NumPy standar.
# *   wandb (Weights & Biases): Library platform Machine Learning Operations (MLOps) yang digunakan untuk melacak eksperimen (tracking), memvisualisasikan matriks pelatihan model (seperti akurasi dan loss), serta mengelola versi model.
# *   pyECG: Library yang menyediakan Tool untuk memproses, menganalisis, dan mengekstraksi fitur-fitur klinis dari sinyal Electrocardiography (ECG/rekaman detak jantung).

# %% [markdown]
# **Bagian 2**

# %% [markdown]
# 1. Pelanggaran Etika dan Hukum dalam Penggunaan AI
# *   Contoh Tindakan : Pembuatan dan penyebaran konten Deepfake (manipulasi wajah dan suara menggunakan AI) tanpa izin untuk tujuan penipuan, pencemaran nama baik, atau pornografi balas dendam (revenge porn). Selain itu, penggunaan karya seni, artikel, atau kode berhak cipta untuk melatih model Generative AI tanpa izin dari kreator asli juga melanggar hak kekayaan intelektual.
# *   Referensi : Undang-Undang Informasi dan Transaksi Elektronik (UU ITE), Kasus Penipuan Deepfake AI Kepala Daerah Gubernur Jawa Timur.

# %% [markdown]
# 2. Dampak AI terhadap lingkungan dan cara mengatasinya
# Memang dengan adanya AI dapat mempermudah pekerjaan manusia, tetapi hal tersebut memiliki dampak yang cukup signifikan pada lingkungan. Pelatihan model AI skala besar membutuhkan pusat data dengan daya komputasi yang sangat masif. Hal ini berdampak pada hasil karbon (emisi CO2) yang tinggi akibat konsumsi listrik yang besar, serta penggunaan jutaan liter air bersih yang dibutuhkan untuk mendinginkan server (cooling system) agar tidak overheat. Cara mengatasinya ada beberapa cara, yakni memindahkan pasokan listrik pusat data dari bahan bakar fosil ke sumber energi bersih (tenaga surya, angin, air), karena faktor emisi sangat bergantung pada bauran energi. Misalnya emisi listrik di Norwegia/Swedia kurang dari 30 gram CO₂/kWh berkat energi bersih, dibanding India yang mencapai 600 gram CO₂/kWh. Kemudian menciptakan teknologi pendinginan baru yang lebih hemat energi dan air. Referensi : Strubell, E., Ganesh, A., & McCallum, A. (2019). Energy and Policy Considerations for Deep Learning in NLP, Analisis Dampak Lingkungan Data Center di Indonesia pada Era AI: Tinjauan Emisi Karbon dan Penggunaan Lahan dalam Perspektif Green Computing.
